# %% [markdown]
# ## CS 6120: Natural Language Processing - Prof. Ahmad Uzair
#
# ### Assignment 1: Naive Bayes
# ### Total Points: 100 points
#
# In this assignment, you would be working with SMS data that contains SPAM or HAM messages. When you take a look at your gmail account, you find that a few emails are classified as spam. Similarly, some text messages that are received on the phone are also classified as spam based on a set of characteristics such as wording and so on.
#
# Therefore, we are going to address this problem of detecting SPAM or HAM messages with the help of Naive Bayes algorithm.
#
# ## Importing the Libraries

# %%
import numpy as np
import pandas as pd
import re
import nltk
from nltk.corpus import stopwords
from nltk.stem import PorterStemmer
from nltk.tokenize import word_tokenize
import warnings
import seaborn as sns
import matplotlib.pyplot as plt
warnings.filterwarnings("ignore")

# %% [markdown]
# ## Reading the data
#
# When reading the data, ensure that the '.csv' file is in the same location where your jupyter notebook is used. This way the files are organized and easy to read using the pandas library.

# %%
## Reading the data and removing columns that are not important. 
df = pd.read_csv('spam.csv', sep = ',', encoding = 'latin-1', usecols = lambda col: col not in ["Unnamed: 2", "Unnamed: 3", "Unnamed: 4"])

# %%
None  # print head of data frame with help of head function
df.head()
# Out:
#      v1                                                 v2
# 0   ham  Go until jurong point, crazy.. Available only ...
# 1   ham                      Ok lar... Joking wif u oni...
# 2  spam  Free entry in 2 a wkly comp to win FA Cup fina...
# 3   ham  U dun say so early hor... U c already then say...
# 4   ham  Nah I don't think he goes to usf, he lives aro...

# %%
## Renaming the columns so that we understand the columns easily.
## Rename v1 as "spam_or_ham" and v2 as "message"
df = df.rename(columns = {'v1': 'spam_or_ham', 'v2': 'message'})

# %%
# print head of data frame with help of head function 
df.head()
# Out:
#   spam_or_ham                                            message
# 0         ham  Go until jurong point, crazy.. Available only ...
# 1         ham                      Ok lar... Joking wif u oni...
# 2        spam  Free entry in 2 a wkly comp to win FA Cup fina...
# 3         ham  U dun say so early hor... U c already then say...
# 4         ham  Nah I don't think he goes to usf, he lives aro...

# %% [markdown]
# ## Count plot of the output categories: spam or ham
#
# Feel free to take a look at the output and whether the classes are balanced or imbalanced.

# %%
plt.figure(figsize = (8,8))
sns.countplot(x ='spam_or_ham', data = df)
plt.title("Spam Vs. Ham Messages count", fontsize = 15)
plt.show()

# %% [markdown]
# ## Upsampling the minority class: (5 points)
#
# It is known that Naive bayes is not robust to class imbalance. It could be seen above that the data is quite imbalanced. Therefore, class balancing must be done before giving it to the Naive Bayes model for prediction.
#
# Feel free to use 'resample' library from sklearn.

# %%
## hint: use resample from sklearn.utils
from sklearn.utils import resample

df_majority = df[df['spam_or_ham'] == 'ham']
df_minority = df[df['spam_or_ham'] == 'spam']

spam_upsample = resample(df_minority, replace = True, 
                        n_samples = df_majority.shape[0],
                        random_state = 101)

# concat two data frames i,e majority class data set and upsampled minority class data set
df_upsampled = pd.concat([spam_upsample,df_majority])  
df_upsampled = df_upsampled.sample(frac = 1)

# %%
## Just to ensure that upsampling was done successfully, take a look at the shape of the data in 
## this cell. 

# print the shape of data set with the help of shape function having "spam" as class label
#np.shape(spam_upsample)
df_upsampled[df_upsampled.spam_or_ham == 'spam'].shape
# Out:
# (4825, 2)

# %% [markdown]
# ### Expected Output :
# (4825, 2)

# %%
## Ensure that the same number of data points are present for both 'spam' and 'ham' data

# print the shape of data set with the help of shape function having "ham" as class label
df_upsampled[df_upsampled.spam_or_ham == 'ham'].shape
# Out:
# (4825, 2)

# %% [markdown]
# ### Expected Output :
# (4825, 2)

# %%
## In this cell, we are going to be dividing the data into train and test points
## Ensure that you store the upsampled data in a variable called 'df_upsampled' 
## so that the below operations are performed successfully


## Considering 3000 spam and 3000 ham data points
spam_data_points_train = df_upsampled[(df_upsampled["spam_or_ham"] == 'spam') ].iloc[:3000]
ham_data_points_train = df_upsampled[(df_upsampled["spam_or_ham"] == 'ham') ].iloc[:3000]

## Considering the remaining data points for test
spam_data_points_test = df_upsampled[(df_upsampled["spam_or_ham"] == 'spam') ].iloc[3000:]
ham_data_points_test = df_upsampled[(df_upsampled["spam_or_ham"] == 'ham') ].iloc[3000:]

## Concatenate the training ham and spam messages
X_train = pd.concat([spam_data_points_train['message'], ham_data_points_train['message']])
## Concatenating the training ham and spam outputs
y_train = pd.concat([spam_data_points_train['spam_or_ham'], ham_data_points_train['spam_or_ham']])

## Concatenating the test ham and spam messages
X_test = pd.concat([spam_data_points_test['message'], ham_data_points_test['message']])
## Concatenating the test ham and spam outputs
y_test = pd.concat([spam_data_points_test['spam_or_ham'], ham_data_points_test['spam_or_ham']])

# %%
## Take a look at the total number of classes and their count using '.value_counts()' for y_train and y_test.
## Ensure that there are equal number of spam and ham messages.
y_train.value_counts()
# Out:
# spam    3000
# ham     3000
# Name: spam_or_ham, dtype: int64

# %% [markdown]
# ### Expected Output:
# spam    3000<br>
# ham     3000<br>
# Name: spam_or_ham, dtype: int64

# %%
y_test.value_counts()
# Out:
# spam    1825
# ham     1825
# Name: spam_or_ham, dtype: int64

# %% [markdown]
# ### Expected Output :
# spam    1825<br>
# ham     1825<br>
# Name: spam_or_ham, dtype: int64

# %%
nltk.download('stopwords')
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /Users/yashvibhandari/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to
# [nltk_data]     /Users/yashvibhandari/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %% [markdown]
# ## Pre-process the messages: (15 points)
#
# We know that a message contains links, punctuation, stopwords and many other words that don't give a lot of meaning for the Naive Bayes model for prediction.
#
# In the cell below, one must implement text-preprocessing and remove links, punctuations and stopwords. It is also important to lowercase the letters so that 'Admire' and 'admire' are not treated as different words.
#
# In addition to this, perform stemming operation so that similar words are reduced. To know more about stemming, feel free to take a look at this link.
#
# https://nlp.stanford.edu/IR-book/html/htmledition/stemming-and-lemmatization-1.html

# %%
# TASK CELL

def clean_message(message):
    
    '''
    Input:
        message: a string containing a message.
    Output:
        messages_cleaned: a list of words containing the processed message. 

    '''

    ps = PorterStemmer()
    #message = message.lower()
    Words= word_tokenize(message)
    messages=[word for word in Words if word not in stopwords.words('english')]
    messages_cleaned = [ps.stem(word) for word in messages]
    
    #stop_words = set(stopwords.words("english"))
    #message = " ".join([w for w in message.split() if w not in stop_words])
    #message = " ".join(char for char in message.split() if char.isalnum())
    #ps = PorterStemmer()
    #words = ps.stem(message)
    #messages_cleaned = list(words.split(" "))
    
    return messages_cleaned

# %%
#print(clean_message("Programmers program with programming languages retrieval"))

# %% [markdown]
# ## Implement a find_occurrence function (5 points):
#
# In this function, we find the total occurrence of a word giving information such as label, word and frequency dictionary.
#
# Note that this function is used later in the code when we are going to be predicting the output using Naive Bayes.

# %%
# TASK CELL
def find_occurrence(frequency, word, label):
    '''
    Params:
        frequency: a dictionary with the frequency of each pair (or tuple)
        word: the word to look up
        label: the label corresponding to the word
    Return:
        n: the number of times the word with its corresponding label appears.
    '''
    n = 0
    pair = (word, label)
    '''for pair in list(frequency.keys()):
        if pair in key:
            n = print(value)'''
    if pair in frequency:
        n = frequency[pair]
        
    return n

# %% [markdown]
# ## Converting output to numerical format:
#
# We have outputs as 'ham' or 'spam'. In the cell below, we convert it to a numerical format.

# %%
## With the use of mapping function, we replace
## the label in the form of string to an integer. 

output_map = {'ham': 0, 'spam': 1}
y_train = y_train.map(output_map)
y_test = y_test.map(output_map)

# %%
## Ensuring that there are equal number of classes on the training data. 
y_train.value_counts()
# Out:
# 1    3000
# 0    3000
# Name: spam_or_ham, dtype: int64

# %%
## Choosing a random message and taking a look at it.
X_train.iloc[0]
# Out:
# 'Your B4U voucher w/c 27/03 is MARSMS. Log onto www.B4Utele.com for discount credit. To opt out reply stop. Customer care call 08717168528'

# %% [markdown]
# From the above cell output, it could be seen that there are a lot of words that don't add a lot of meaning to the text.
#
# Therefore, those words would be removed. It also reduces the computation time.
#
# Therefore, it is a good practice we are following.

# %%
custom_message = X_train.iloc[0]

# print cleaned message
print(clean_message(custom_message))
# Out:
# ['your', 'b4u', 'voucher', 'w/c', '27/03', 'marsm', '.', 'log', 'onto', 'www.b4utele.com', 'discount', 'credit', '.', 'to', 'opt', 'repli', 'stop', '.', 'custom', 'care', 'call', '08717168528']

# %% [markdown]
# We now use this function to pre-process the message and remove words that don't add a lot of meaning in our model.

# %% [markdown]
# ## Implementing message counter function: (10 points)
#
# It is now time to implement the count function for the messages.
#
# In this function, we count the occurrence of words and get the probabilities
# for the words based on the training data.
#
# In other words, we get the probability of occurrence of a word, given that the output is 'spam'.
#
# Similarly, we also compute the probability of occurence of a word, given that the output is 'ham'.

# %%
# TASK CELL
def message_counter(output_occurrence, messages, spam_or_ham):
    '''
    Params:
        output_occurrence: a dictionary that will be used to map each pair to its frequency
        messages: a list of messages
        spam_or_ham: a list corresponding to the sentiment of each message (either 0 or 1)
    Return:
        output: a dictionary mapping each pair to its frequency
    '''
    ## Steps :
    # define the key, which is the word and label tuple
    # if the key exists in the dictionary, increment the count
    # else, if the key is new, add it to the dictionary and set the count to 1
    
    for label, message in zip(spam_or_ham, messages):
        for word in clean_message(message):
            if (word, label) in list(output_occurrence.keys()):
                output_occurrence[(word, label)] += 1
            else:
                output_occurrence[(word, label)] = 1

    return output_occurrence

# %% [markdown]
# ## Test your function with example messages:
#
# Feel free to run the cell below and understand whether the above function that you have defined is producing the optimum results.

# %%
# Testing your function

result = {}
messages = ['get offer upto 20%', 'I am coming now', 'Click on the link', 'get a latest car', 'canvas class scheduled']
ys = [1, 0, 1, 1, 0]
message_counter(result,messages, ys)
# Out:
# {('get', 1): 2,
#  ('offer', 1): 1,
#  ('upto', 1): 1,
#  ('20', 1): 1,
#  ('%', 1): 1,
#  ('i', 0): 1,
#  ('come', 0): 1,
#  ('click', 1): 1,
#  ('link', 1): 1,
#  ('latest', 1): 1,
#  ('car', 1): 1,
#  ('canva', 0): 1,
#  ('class', 0): 1,
#  ('schedul', 0): 1}

# %% [markdown]
# ### Expected Output:
# {('get', 1): 2, <br>
#  ('offer', 1): 1, <br>
#  ('upto', 1): 1, <br>
#  ('20', 1): 1, <br>
#  ('i', 0): 1, <br>
#  ('come', 0): 1, <br>
#  ('click', 1): 1, <br>
#  ('link', 1): 1, <br>
#  ('latest', 1): 1, <br>
#  ('car', 1): 1, <br>
#  ('canva', 0): 1, <br>
#  ('class', 0): 1, <br>
#  ('schedul', 0): 1}

# %%
# Build the freqs dictionary for later uses

freqs = message_counter({}, X_train, y_train)

# %%
## Run this cell to get an idea about the corpus of words and their occurrence along with labels. 
## In this, we are computing the frequency of occurrence of word given that a message is 'spam'.
## Similarly, we also compute the frequence of occurence of word given that a message is 'ham'.
freqs
# Out:
# {('your', 1): 314,
#  ('b4u', 1): 8,
#  ('voucher', 1): 152,
#  ('w/c', 1): 8,
#  ('27/03', 1): 8,
#  ('marsm', 1): 8,
#  ('.', 1): 3919,
#  ('log', 1): 42,
#  ('onto', 1): 42,
#  ('www.b4utele.com', 1): 8,
#  ('discount', 1): 38,
#  ('credit', 1): 76,
#  ('to', 1): 289,
#  ('opt', 1): 51,
#  ('repli', 1): 494,
#  ('stop', 1): 483,
#  ('custom', 1): 204,
#  ('care', 1): 30,
#  ('call', 1): 1394,
#  ('08717168528', 1): 8,
#  ('tell', 1): 81,
#  ('u', 1): 606,
#  ('2', 1): 744,
#  ('09066358152', 1): 8,
#  ('claim', 1): 446,
#  ('å£5000', 1): 72,
#  ('prize', 1): 382,
#  ('enter', 1): 49,
#  ('ur', 1): 631,
#  ('mobil', 1): 554,
#  ('&', 1): 743,
#  ('person', 1): 13,
#  ('detail', 1): 28,
#  ('@', 1): 106,
#  ('prompt', 1): 8,
#  ('!', 1): 2175,
#  ('urgent', 1): 214,
#  ('pleas', 1): 225,
#  ('09061213237', 1): 5,
#  ('landlin', 1): 114,
#  ('cash', 1): 229,
#  ('4', 1): 498,
#  ('*', 1): 393,
#  ('holiday', 1): 120,
#  ('await', 1): 114,
#  ('collect', 1): 206,
#  ('t', 1): 254,
#  ('cs', 1): 162,
#  ('sae', 1): 82,
#  ('po', 1): 106,
#  ('box', 1): 105,
#  ('177', 1): 5,
#  ('m227xi', 1): 5,
#  ('16+', 1): 105,
#  ('wan2', 1): 9,
#  ('win', 1): 248,
#  ('meet+greet', 1): 9,
#  ('westlif', 1): 9,
#  ('m8', 1): 18,
#  ('?', 1): 719,
#  ('they', 1): 16,
#  ('current', 1): 58,
#  ('tour', 1): 11,
#  ('1', 1): 145,
#  (')', 1): 257,
#  ('unbreak', 1): 9,
#  (',', 1): 1413,
#  ('untam', 1): 9,
#  ('3', 1): 124,
#  ('unkempt', 1): 9,
#  ('text', 1): 535,
#  ('1,2', 1): 9,
#  ('83049', 1): 9,
#  ('cost', 1): 93,
#  ('50p', 1): 23,
#  ('+std', 1): 9,
#  ('uniqu', 1): 13,
#  ('user', 1): 45,
#  ('id', 1): 7,
#  ('1172', 1): 7,
#  ('for', 1): 154,
#  ('remov', 1): 31,
#  ('send', 1): 282,
#  ('87239', 1): 27,
#  ('servic', 1): 258,
#  ('08708034412', 1): 14,
#  ('you', 1): 388,
#  ('special', 1): 74,
#  ('select', 1): 130,
#  ('receiv', 1): 168,
#  ('\\3000', 1): 4,
#  ('award', 1): 284,
#  ('08712402050', 1): 10,
#  ('befor', 1): 10,
#  ('line', 1): 139,
#  ('close', 1): 18,
#  ('10ppm', 1): 10,
#  ('appli', 1): 108,
#  ('ag', 1): 10,
#  ('promo', 1): 10,
#  ("''", 1): 85,
#  ('bore', 1): 21,
#  ('housew', 1): 7,
#  ('chat', 1): 181,
#  ('n', 1): 37,
#  ('date', 1): 96,
#  ('0871750.77.11', 1): 7,
#  ('bt-nation', 1): 7,
#  ('rate', 1): 116,
#  ('10p/min', 1): 27,
#  ('winner', 1): 62,
#  ('as', 1): 50,
#  ('valu', 1): 52,
#  ('network', 1): 122,
#  ('receivea', 1): 13,
#  ('å£900', 1): 27,
#  ('reward', 1): 53,
#  ('09061701461', 1): 13,
#  ('code', 1): 110,
#  ('kl341', 1): 13,
#  ('valid', 1): 80,
#  ('12', 1): 22,
#  ('hour', 1): 27,
#  ('new', 1): 297,
#  ('messag', 1): 165,
#  ('08715205273', 1): 4,
#  ('we', 1): 128,
#  ('know', 1): 97,
#  ('someon', 1): 40,
#  ('fanci', 1): 32,
#  ('09058097218', 1): 1,
#  ('find', 1): 82,
#  ('pobox', 1): 64,
#  ('6', 1): 21,
#  ('ls15hb', 1): 2,
#  ('150p', 1): 95,
#  ('no', 1): 186,
#  ('å£2,000', 1): 52,
#  ('bonu', 1): 84,
#  ('caller', 1): 52,
#  ('1/08/03', 1): 3,
#  ('thi', 1): 179,
#  ('2nd', 1): 92,
#  ('attempt', 1): 100,
#  ('contact', 1): 236,
#  ('0871-4719-523', 1): 3,
#  ('box95qu', 1): 8,
#  ('bt', 1): 21,
#  ('nation', 1): 38,
#  ('guarante', 1): 196,
#  ('å£200', 1): 50,
#  ('even', 1): 28,
#  ('å£1000', 1): 138,
#  ('cashto', 1): 13,
#  ('free', 1): 958,
#  ('08000407165', 1): 13,
#  ('(', 1): 202,
#  ('18+', 1): 70,
#  ('getstop', 1): 13,
#  ('88222', 1): 13,
#  ('php', 1): 13,
#  ('chanc', 1): 116,
#  ('å£250', 1): 47,
#  ('everi', 1): 148,
#  ('wk', 1): 70,
#  ('txt', 1): 699,
#  (':', 1): 628,
#  ('action', 1): 12,
#  ('80608', 1): 5,
#  ("'s", 1): 280,
#  ('c', 1): 182,
#  ('www.movietrivia.tv', 1): 5,
#  ('custcar', 1): 32,
#  ('08712405022', 1): 5,
#  ('1x150p/wk', 1): 19,
#  ('freemsg', 1): 56,
#  ('flirt', 1): 24,
#  ('join', 1): 72,
#  ('uk', 1): 93,
#  ('fastest', 1): 9,
#  ('grow', 1): 9,
#  ('msg', 1): 135,
#  ('rcvd', 1): 31,
#  ('25p', 1): 29,
#  ('optout', 1): 26,
#  ('83021', 1): 5,
#  ('today', 1): 166,
#  ('vodafon', 1): 25,
#  ('number', 1): 152,
#  ('end', 1): 108,
#  ('0089', 1): 4,
#  ('last', 1): 54,
#  ('four', 1): 4,
#  ('digit', 1): 40,
#  ('å£350', 1): 65,
#  ('if', 1): 71,
#  ('match', 1): 61,
#  ('09063442151', 1): 4,
#  ('ye', 1): 58,
#  ('the', 1): 126,
#  ('place', 1): 28,
#  ('town', 1): 14,
#  ('meet', 1): 27,
#  ('excit', 1): 16,
#  ('adult', 1): 18,
#  ('singl', 1): 24,
#  ('86688', 1): 93,
#  ('150p/msg', 1): 72,
#  ('å£150', 1): 34,
#  ('worth', 1): 51,
#  ('vouchers-text', 1): 5,
#  ('85023', 1): 28,
#  ('savamob-memb', 1): 5,
#  ('offer', 1): 161,
#  ('08717898035.', 1): 12,
#  ('å£3.00', 1): 28,
#  ('sub', 1): 34,
#  ('16', 1): 108,
#  ('x', 1): 33,
#  ('r', 1): 132,
#  ('subscrib', 1): 33,
#  ('textcomp', 1): 6,
#  ('250', 1): 19,
#  ('wkli', 1): 67,
#  ('comp', 1): 35,
#  ('1st', 1): 126,
#  ('question', 1): 41,
#  ('follow', 1): 48,
#  ('subsequ', 1): 6,
#  ('charg', 1): 115,
#  ('150p/msg.2', 1): 6,
#  ('unsubscrib', 1): 65,
#  ('84128', 1): 13,
#  ('08712405020', 1): 16,
#  ('hi', 1): 61,
#  ('sexychat', 1): 4,
#  ('girl', 1): 38,
#  ('wait', 1): 59,
#  ('great', 1): 45,
#  ('night', 1): 28,
#  ("n't", 1): 73,
#  ('go', 1): 144,
#  ('anoth', 1): 7,
#  ('www.t-c.biz', 1): 7,
#  ('150p/min', 1): 12,
#  ('polo', 1): 7,
#  ('ltd', 1): 51,
#  ('suit', 1): 7,
#  ('373', 1): 7,
#  ('london', 1): 15,
#  ('w1j', 1): 7,
#  ('6hl', 1): 7,
#  ('back', 1): 84,
#  ('busi', 1): 7,
#  ('shop', 1): 66,
#  ('spree', 1): 38,
#  ('week', 1): 281,
#  ('start', 1): 66,
#  ('now', 1): 262,
#  ('play', 1): 88,
#  ('store', 1): 37,
#  ('88039', 1): 15,
#  ('skilgm', 1): 15,
#  ('tscs08714740323', 1): 9,
#  ('1winawk', 1): 9,
#  ('age16', 1): 29,
#  ('å£1.50perweeksub', 1): 9,
#  ('show', 1): 127,
#  ('colour', 1): 88,
#  ('euro', 1): 14,
#  ('2004', 1): 34,
#  ('2-4-1', 1): 5,
#  ('get', 1): 368,
#  ('england', 1): 36,
#  ('flag', 1): 41,
#  ('3lion', 1): 5,
#  ('tone', 1): 351,
#  ('phone', 1): 223,
#  ('click', 1): 22,
#  ('info', 1): 56,
#  ('4882', 1): 10,
#  ('09064019014', 1): 10,
#  ('88066', 1): 23,
#  ('from', 1): 62,
#  ('lost', 1): 14,
#  ('3pound', 1): 9,
#  ('help', 1): 60,
#  ('had', 1): 70,
#  ('10', 1): 34,
#  ('mth', 1): 17,
#  ('updat', 1): 99,
#  ('latest', 1): 167,
#  ('camera/video', 1): 8,
#  ('keep', 1): 21,
#  ('same', 1): 4,
#  ('extra', 1): 26,
#  ('mins/text', 1): 4,
#  ('11', 1): 19,
#  ('month', 1): 39,
#  ('entitl', 1): 40,
#  ('camera', 1): 139,
#  ('co', 1): 29,
#  ('08002986030', 1): 14,
#  ('18', 1): 92,
#  ('day', 1): 144,
#  ('euro2004', 1): 18,
#  ('kickoff', 1): 9,
#  ('kept', 1): 13,
#  ('inform', 1): 54,
#  ('news', 1): 27,
#  ('result', 1): 13,
#  ('daili', 1): 16,
#  ('83222', 1): 13,
#  ('08712402902', 1): 2,
#  ('immedi', 1): 10,
#  ('sm', 1): 90,
#  ('inclus', 1): 21,
#  ('pl', 1): 37,
#  ('goto', 1): 22,
#  ('www.comuk.net', 1): 20,
#  ('login=', 1): 16,
#  ('3qxj9', 1): 16,
#  ('08702840625.comuk', 1): 12,
#  ('220-cm2', 1): 12,
#  ('9ae', 1): 16,
#  ('09061743811', 1): 3,
#  ('abta', 1): 11,
#  ('complimentari', 1): 47,
#  ('tenerif', 1): 32,
#  ('326', 1): 9,
#  ('cw25wx', 1): 16,
#  ('150ppm', 1): 125,
#  ('-', 1): 216,
#  ('sipix', 1): 20,
#  ('09061221066', 1): 11,
#  ('fromm', 1): 11,
#  ('deliveri', 1): 77,
#  ('within', 1): 22,
#  ('28', 1): 14,
#  ('loyalti', 1): 22,
#  ('nokia6650', 1): 7,
#  ('onli', 1): 98,
#  ('å£10', 1): 16,
#  ('txtauction', 1): 20,
#  ('word', 1): 88,
#  ('81151', 1): 7,
#  ('4t', 1): 13,
#  ('ctxt', 1): 7,
#  ('tc', 1): 39,
#  ('150p/mtmsg', 1): 7,
#  ('orang', 1): 117,
#  ('may', 1): 21,
#  ('upgrad', 1): 15,
#  ('0207', 1): 6,
#  ('153', 1): 6,
#  ('9996', 1): 2,
#  ('14thmarch', 1): 2,
#  ('opt-out', 1): 14,
#  ('availa', 1): 2,
#  ('80878', 1): 15,
#  ('www.txt-2-shop.com', 1): 10,
#  ('08715705022', 1): 19,
#  ('panason', 1): 5,
#  ('bluetoothhdset', 1): 5,
#  ('nokia', 1): 297,
#  ('motorola', 1): 38,
#  ('doublemin', 1): 5,
#  ('doubletxt', 1): 5,
#  ('contract', 1): 17,
#  ('mobileupd8', 1): 66,
#  ('08000839402', 1): 62,
#  ('2optout', 1): 19,
#  ('ac', 1): 21,
#  ('sptv', 1): 8,
#  ('jersey', 1): 4,
#  ('devil', 1): 4,
#  ('detroit', 1): 4,
#  ('red', 1): 4,
#  ('wing', 1): 4,
#  ('ice', 1): 4,
#  ('hockey', 1): 4,
#  ('correct', 1): 19,
#  ('incorrect', 1): 4,
#  ('will', 1): 16,
#  ('dream', 1): 14,
#  ('partner', 1): 13,
#  ('soon', 1): 10,
#  ('is', 1): 45,
#  ('career', 1): 4,
#  ('flyng', 1): 4,
#  ('horo', 1): 8,
#  ('star', 1): 15,
#  ('sign', 1): 8,
#  ('e.', 1): 7,
#  ('g.', 1): 13,
#  ('ari', 1): 4,
#  ('trip', 1): 12,
#  ('eurodisinc', 1): 7,
#  ('trav', 1): 7,
#  ('aco', 1): 7,
#  ('entry41', 1): 7,
#  ('or', 1): 12,
#  ('di', 1): 7,
#  ('87121', 1): 11,
#  ('18+6', 1): 7,
#  ('å£1.50', 1): 74,
#  ('morefrmmob', 1): 7,
#  ('shracomorsglsuplt', 1): 7,
#  ('ls1', 1): 7,
#  ('3aj', 1): 7,
#  ('want', 1): 122,
#  ('laid', 1): 15,
#  ('tonight', 1): 17,
#  ('real', 1): 49,
#  ('dog', 1): 46,
#  ('locat', 1): 19,
#  ('sent', 1): 43,
#  ('direct', 1): 43,
#  ('mob', 1): 108,
#  ('largest', 1): 15,
#  ('txting', 1): 53,
#  ('gravel', 1): 6,
#  ('69888', 1): 10,
#  ('nt', 1): 6,
#  ('ec2a', 1): 15,
#  ('31p.msg', 1): 7,
#  ('secret', 1): 41,
#  ('admir', 1): 41,
#  ('reveal', 1): 64,
#  ('think', 1): 55,
#  ('so', 1): 7,
#  ('09065174042', 1): 7,
#  ('1.50', 1): 9,
#  ('per', 1): 195,
#  ('recd', 1): 13,
#  ('cust', 1): 13,
#  ('07821230901', 1): 7,
#  ('time', 1): 85,
#  ('tri', 1): 148,
#  ('u.', 1): 65,
#  ('750', 1): 78,
#  ('pound', 1): 104,
#  ('easi', 1): 60,
#  ('08718726970', 1): 6,
#  ('10p', 1): 67,
#  ('min', 1): 205,
#  ('bt-national-r', 1): 43,
#  ('not', 1): 15,
#  ('heard', 1): 15,
#  ('u4', 1): 15,
#  ('knicker', 1): 4,
#  ('make', 1): 48,
#  ('beg', 1): 4,
#  ('like', 1): 54,
#  ('01223585236', 1): 4,
#  ('xx', 1): 12,
#  ('luv', 1): 21,
#  ('nikiyu4.net', 1): 4,
#  ('do', 1): 60,
#  ('ever', 1): 9,
#  ('notic', 1): 12,
#  ("'re", 1): 13,
#  ('drive', 1): 10,
#  ('anyon', 1): 5,
#  ('slower', 1): 5,
#  ('idiot', 1): 5,
#  ('everyon', 1): 10,
#  ('faster', 1): 5,
#  ('maniac', 1): 5,
#  ('filthi', 1): 11,
#  ('stori', 1): 4,
#  ('3510i', 1): 21,
#  ('deliveredtomorrow', 1): 13,
#  ('with', 1): 30,
#  ('300', 1): 20,
#  ('minut', 1): 57,
#  ('+', 1): 72,
#  ('100', 1): 71,
#  ('camcord', 1): 59,
#  ('08000930705', 1): 68,
#  ('privat', 1): 66,
#  ('account', 1): 69,
#  ('statement', 1): 55,
#  ('07742676969', 1): 6,
#  ('786', 1): 15,
#  ('unredeem', 1): 15,
#  ('point', 1): 57,
#  ('08719180248', 1): 6,
#  ('identifi', 1): 57,
#  ('45239', 1): 11,
#  ('expir', 1): 65,
#  ('natali', 1): 4,
#  ('20/f', 1): 4,
#  ('invit', 1): 55,
#  ('friend', 1): 74,
#  ('yes-165', 1): 4,
#  ('no-165', 1): 4,
#  ('see', 1): 76,
#  ('www.sms.ac/u/natalie2k9', 1): 4,
#  ('frnd', 1): 31,
#  ('62468', 1): 31,
#  ('local', 1): 15,
#  ('area', 1): 32,
#  ('lot', 1): 4,
#  ('peopl', 1): 7,
#  ('regist', 1): 26,
#  ('www.flirtparty.u', 1): 3,
#  ('replys150', 1): 3,
#  ('goldvik', 1): 4,
#  ('29/m', 1): 4,
#  ('yes-762', 1): 4,
#  ('no-762', 1): 4,
#  ('www.sms.ac/u/goldvik', 1): 4,
#  ('entri', 1): 102,
#  ('textpod', 1): 7,
#  ('40gb', 1): 23,
#  ('ipod', 1): 45,
#  ('pod', 1): 16,
#  ('ts', 1): 37,
#  ('www.textpod.net', 1): 7,
#  ('mnth', 1): 5,
#  ('etc', 1): 21,
#  ('doubl', 1): 72,
#  ('tariff', 1): 20,
#  ('callback', 1): 9,
#  ('record', 1): 21,
#  ('be', 1): 5,
#  ('on', 1): 23,
#  ('a', 1): 75,
#  ('realiti', 1): 5,
#  ('fantasi', 1): 38,
#  ('=', 1): 12,
#  ('08707509020', 1): 25,
#  ('just', 1): 126,
#  ('20p', 1): 27,
#  ('ntt', 1): 33,
#  ('1327', 1): 27,
#  ('croydon', 1): 27,
#  ('cr9', 1): 27,
#  ('5wb', 1): 27,
#  ('0870', 1): 30,
#  ('2003', 1): 44,
#  ('800', 1): 44,
#  ('un-redeem', 1): 42,
#  ('s.', 1): 32,
#  ('i.', 1): 32,
#  ('m.', 1): 32,
#  ('08719899230', 1): 3,
#  ('41685', 1): 7,
#  ('07/11/04', 1): 7,
#  ('work', 1): 16,
#  ('2morro', 1): 6,
#  ('half', 1): 58,
#  ('term', 1): 47,
#  ('can', 1): 18,
#  ('2nite', 1): 16,
#  ('sexi', 1): 55,
#  ('passion', 1): 6,
#  ('b4', 1): 27,
#  ('i', 1): 154,
#  ('09099726481', 1): 6,
#  ('dena', 1): 6,
#  ('å£1/minmobsmorelkpobox177hp51fl', 1): 6,
#  ('anytim', 1): 52,
#  ('150', 1): 35,
#  ('video', 1): 124,
#  ('five', 1): 13,
#  ('08002888812', 1): 7,
#  ('tomorrow', 1): 36,
#  ('cd', 1): 77,
#  ('4u', 1): 19,
#  ('congratul', 1): 73,
#  ('å£500', 1): 70,
#  ('gift', 1): 85,
#  ('å£125', 1): 7,
#  ('freeentri', 1): 7,
#  ('å£100', 1): 104,
#  ('draw', 1): 179,
#  ('xt', 1): 7,
#  ('music', 1): 98,
#  ('87066', 1): 70,
#  ('tnc', 1): 41,
#  ('www.ldew.com1win150ppmx3age16', 1): 20,
#  ('rington', 1): 163,
#  ('simpli', 1): 13,
#  ('password', 1): 13,
#  ('\\mix\\', 1): 9,
#  ('85069', 1): 9,
#  ('verifi', 1): 14,
#  ('usher', 1): 9,
#  ('britney', 1): 9,
#  ('fml', 1): 9,
#  ('hey', 1): 23,
#  ('boy', 1): 10,
#  ('hot', 1): 58,
#  ('xxx', 1): 51,
#  ('pic', 1): 114,
#  ('porn', 1): 22,
#  ('69855', 1): 8,
#  ('24hr', 1): 10,
#  ('stopbcm', 1): 8,
#  ('sf', 1): 8,
#  ('wc1n3xx', 1): 17,
#  ('block', 1): 4,
#  ('breaker', 1): 4,
#  ('come', 1): 21,
#  ('delux', 1): 4,
#  ('format', 1): 4,
#  ('featur', 1): 4,
#  ('graphic', 1): 4,
#  ('t-mobil', 1): 13,
#  ('buy', 1): 14,
#  ('å£5', 1): 4,
#  ('bbdelux', 1): 4,
#  ('take', 1): 71,
#  ('challeng', 1): 4,
#  ('u\x89ûªv', 1): 5,
#  ('bin', 1): 5,
#  ('å£50', 1): 5,
#  ('instant', 1): 5,
#  ('08715203028', 1): 5,
#  ('9th', 1): 5,
#  ('player', 1): 45,
#  ('å£50-å£500', 1): 5,
#  ('08718727870', 1): 7,
#  ('1/2', 1): 12,
#  ('price', 1): 65,
#  ('linerent', 1): 17,
#  ('bluetooth', 1): 37,
#  ('call2optout/lf56', 1): 11,
#  ('sun0819', 1): 9,
#  ('post', 1): 26,
#  ('hello', 1): 21,
#  ('\\you', 1): 9,
#  ('seem', 1): 9,
#  ('cool', 1): 9,
#  ('loan', 1): 15,
#  ('purpos', 1): 12,
#  ('å£75,000', 1): 9,
#  ('homeown', 1): 9,
#  ('tenant', 1): 12,
#  ('welcom', 1): 34,
#  ('have', 1): 23,
#  ('previous', 1): 9,
#  ('refus', 1): 12,
#  ('still', 1): 22,
#  ('0800', 1): 44,
#  ('1956669', 1): 9,
#  ("'help", 1): 12,
#  ("'", 1): 22,
#  ('flight', 1): 26,
#  ('inc', 1): 33,
#  ('speak', 1): 35,
#  ('live', 1): 114,
#  ('oper', 1): 54,
#  ('0871277810810', 1): 7,
#  ('å£2000', 1): 63,
#  ('09061790121', 1): 8,
#  ('land', 1): 55,
#  ('3030', 1): 19,
#  ('12hr', 1): 54,
#  ('07xxxxxxxxx', 1): 18,
#  ('02/06/03', 1): 25,
#  ('reach', 1): 26,
#  ('09066362231', 1): 22,
#  ('asap', 1): 30,
#  ('box97n7qp', 1): 17,
#  ('accordingli', 1): 4,
#  ('repeat', 1): 4,
#  ('ok', 1): 19,
#  ('7250i', 1): 13,
#  ('auction', 1): 59,
#  ('part', 1): 41,
#  ('86021', 1): 19,
#  ('hg/suite342/2land', 1): 35,
#  ('row/w1jhl', 1): 13,
#  ("'m", 1): 28,
#  ('sue', 1): 8,
#  ('20', 1): 11,
#  ('year', 1): 58,
#  ('old', 1): 9,
#  ('lapdanc', 1): 4,
#  ('love', 1): 37,
#  ('sex', 1): 36,
#  ('bedroom', 1): 4,
#  ('89555', 1): 7,
#  ('by', 1): 8,
#  ('textoper', 1): 7,
#  ('g2', 1): 4,
#  ('1da', 1): 4,
#  ('150ppmsg', 1): 4,
#  ('nok', 1): 10,
#  ('87021', 1): 16,
#  ('txtin', 1): 17,
#  ('150p/tone', 1): 24,
#  ('hl', 1): 23,
#  ('4info', 1): 17,
#  ('wan', 1): 48,
#  ('na', 1): 37,
#  ('set', 1): 20,
#  ('09096102316', 1): 5,
#  ('cum', 1): 20,
#  ('2moro', 1): 5,
#  ('jane', 1): 5,
#  ('callså£1/minmoremobsemspobox45po139wa', 1): 7,
#  ('knock', 1): 4,
#  ('whose', 1): 2,
#  ('80082', 1): 9,
#  ('weekli', 1): 111,
#  ('yr', 1): 61,
#  ('choic', 1): 9,
#  ('www.tkls.com', 1): 2,
#  ('stoptxtstopå£1.50/week', 1): 2,
#  ('let', 1): 23,
#  ('hg/suite342/2lands/row/w1j6hl', 1): 17,
#  ('ldn', 1): 48,
#  ('08712101358', 1): 10,
#  ('handset', 1): 29,
#  ('unlimit', 1): 40,
#  ('money', 1): 16,
#  ('lucki', 1): 43,
#  ('88600', 1): 8,
#  ('å£1million', 1): 5,
#  ('give', 1): 26,
#  ('away', 1): 13,
#  ('ppt150x3+normal', 1): 5,
#  ('box403', 1): 5,
#  ('w1t1ji', 1): 5,
#  ('blind', 1): 4,
#  ('rodds1', 1): 2,
#  ('21/m', 1): 2,
#  ('aberdeen', 1): 2,
#  ('unit', 1): 2,
#  ('kingdom', 1): 2,
#  ('check', 1): 12,
#  ('him', 1): 2,
#  ('http', 1): 68,
#  ('//img', 1): 2,
#  ('ac/w/icmb3cktz8r7', 1): 2,
#  ('-4', 1): 2,
#  ('hide', 1): 2,
#  ('our', 1): 40,
#  ('indic', 1): 6,
#  ('3750', 1): 2,
#  ('accid', 1): 6,
#  ('congrat', 1): 39,
#  ('3g', 1): 22,
#  ('videophon', 1): 22,
#  ('09063458130', 1): 16,
#  ('videochat', 1): 22,
#  ('wid', 1): 22,
#  ('mate', 1): 67,
#  ('java', 1): 22,
#  ('game', 1): 114,
#  ('dload', 1): 22,
#  ('polyph', 1): 16,
#  ('nolin', 1): 22,
#  ('rentl', 1): 22,
#  ('bx420', 1): 16,
#  ('ip4', 1): 20,
#  ('5we', 1): 20,
#  ('å£800', 1): 29,
#  ('09050001808', 1): 8,
#  ('m95', 1): 8,
#  ('valid12hr', 1): 10,
#  ('cool-mob', 1): 9,
#  ('readi', 1): 26,
#  ('download', 1): 31,
#  ('includ', 1): 11,
#  ('crazi', 1): 17,
#  ('frog-axel', 1): 9,
#  ('f', 1): 25,
#  ('>', 1): 159,
#  ('akon-lon', 1): 9,
#  ('black', 1): 9,
#  ('eyed-dont', 1): 9,
#  ('p', 1): 18,
#  ('more', 1): 44,
#  ('kit', 1): 4,
#  ('strip', 1): 4,
#  ('bill', 1): 27,
#  ('netcollex', 1): 15,
#  ('ltd.', 1): 10,
#  ('1013', 1): 4,
#  ('ig11', 1): 4,
#  ('oja', 1): 4,
#  ('free2day', 1): 13,
#  ('st', 1): 13,
#  ('georg', 1): 13,
#  ('jordan', 1): 17,
#  ('89080', 1): 13,
#  ('dont', 1): 42,
#  ('miss', 1): 37,
#  ('sauci', 1): 16,
#  ('celeb', 1): 14,
#  ('pocketbabe.co.uk', 1): 14,
#  ('0870241182716', 1): 13,
#  ('å£3/wk', 1): 22,
#  ('eeri', 1): 26,
#  ('rpli', 1): 23,
#  ('titl', 1): 24,
#  ('8007', 1): 90,
#  ('eg', 1): 45,
#  ('dracula', 1): 10,
#  ('ghost', 1): 10,
#  ('addamsfa', 1): 10,
#  ('munster', 1): 10,
#  ('exorcist', 1): 10,
#  ('twilight', 1): 10,
#  ('www.getzed.co.uk', 1): 45,
#  ('pobox36504w45wq', 1): 25,
#  ('tbs/persolvo', 1): 5,
#  ('chase', 1): 5,
#  ('us', 1): 19,
#  ('sinc', 1): 10,
#  ('sept', 1): 11,
#  ('forå£38', 1): 5,
#  ('definit', 1): 5,
#  ('pay', 1): 8,
#  ('thank', 1): 79,
#  ('ignor', 1): 5,
#  ('kath', 1): 5,
#  ('manchest', 1): 5,
#  ('09050001295', 1): 5,
#  ('a21', 1): 5,
#  ('ask', 1): 19,
#  ('3mobil', 1): 3,
#  ('chatlin', 1): 3,
#  ('inclu', 1): 3,
#  ('in', 1): 20,
#  ('india', 1): 3,
#  ('serv', 1): 3,
#  ('sed', 1): 3,
#  ('l8er', 1): 3,
#  ('got', 1): 28,
#  ('mega', 1): 3,
#  ('giv', 1): 3,
#  ('shit', 1): 3,
#  ('bailiff', 1): 3,
#  ('due', 1): 6,
#  ('o', 1): 3,
#  ('natalja', 1): 8,
#  ('25/f', 1): 8,
#  ('yes-440', 1): 8,
#  ('no-440', 1): 8,
#  ('www.sms.ac/u/nat27081980', 1): 8,
#  ('voicemail', 1): 7,
#  ('08719181503', 1): 3,
#  ('decemb', 1): 26,
#  ('11mths+', 1): 24,
#  ('08002986906', 1): 20,
#  ('funk', 1): 10,
#  ('fone', 1): 28,
#  ('tones2u', 1): 10,
#  ('www.ringtones.co.uk', 1): 17,
#  ('origin', 1): 17,
#  ('best', 1): 34,
#  ('3gbp', 1): 17,
#  ('well', 1): 21,
#  ('done', 1): 16,
#  ('costa', 1): 28,
#  ('del', 1): 36,
#  ('sol', 1): 28,
#  ('09050090044', 1): 25,
#  ('toclaim', 1): 25,
#  ('pobox334', 1): 25,
#  ('stockport', 1): 25,
#  ('sk38xh', 1): 31,
#  ('costå£1.50/pm', 1): 25,
#  ('max10min', 1): 25,
#  ('bahama', 1): 10,
#  ('callfreefon', 1): 5,
#  ('08081560665', 1): 5,
#  ('either', 1): 44,
#  ('cruis', 1): 5,
#  ('ofå£2000', 1): 5,
#  ('18+onli', 1): 12,
#  ('07786200117', 1): 5,
#  ('good', 1): 56,
#  ('won', 1): 98,
#  ('xma', 1): 84,
#  ('08712103738', 1): 9,
#  ('would', 1): 18,
#  ('nearli', 1): 4,
#  ('ban', 1): 4,
#  ('08719181513', 1): 4,
#  ('cinema', 1): 9,
#  ('pass', 1): 24,
#  ('09061209465', 1): 9,
#  ('suprman', 1): 9,
#  ('v', 1): 17,
#  ('matrix3', 1): 9,
#  ('starwars3', 1): 9,
#  ('bx420-ip4-5w', 1): 9,
#  ('150pm', 1): 17,
#  ('sale', 1): 18,
#  ('arsen', 1): 14,
#  ('dartboard', 1): 4,
#  ('condit', 1): 21,
#  ('trebl', 1): 4,
#  ('dear', 1): 63,
#  ('holder', 1): 19,
#  ('pc', 1): 20,
#  ('//www.e-tlp.co.uk/expressoff', 1): 5,
#  ('80062', 1): 20,
#  ('deliv', 1): 15,
#  ('200', 1): 15,
#  ('where', 1): 7,
#  ('2006', 1): 7,
#  ('fifa', 1): 7,
#  ('world', 1): 11,
#  ('cup', 1): 16,
#  ('held', 1): 7,
#  ('free-messag', 1): 2,
#  ('jamster', 1): 11,
#  ('frog', 1): 2,
#  ('sound', 1): 4,
#  ('poli', 1): 88,
#  ('mad1', 1): 2,
#  ('mad2', 1): 2,
#  ('88888', 1): 7,
#  ('gbp/week', 1): 2,
#  ('16+onli', 1): 6,
#  ('chang', 1): 4,
#  ('25', 1): 11,
#  ('club4mobiles.com', 1): 4,
#  ('choos', 1): 32,
#  ('content', 1): 45,
#  ('club', 1): 79,
#  ('87070', 1): 4,
#  ('150p/wk', 1): 4,
#  ('club4', 1): 4,
#  ('box1146', 1): 4,
#  ('mk45', 1): 4,
#  ('2wt', 1): 4,
#  ('are', 1): 17,
#  ('enough', 1): 13,
#  ('30th', 1): 6,
#  ('august', 1): 7,
#  ('www.areyouunique.co.uk', 1): 6,
#  ('09061743810', 1): 6,
#  ('#', 1): 24,
#  ('5000', 1): 17,
#  ('ppm', 1): 17,
#  ('078498', 1): 5,
#  ('7', 1): 14,
#  ('08719180219', 1): 5,
#  ('06.05.05', 1): 5,
#  ('whi', 1): 28,
#  ('randi', 1): 7,
#  ('femal', 1): 4,
#  ('hear', 1): 12,
#  ('08700621170150p', 1): 8,
#  ('wrc', 1): 8,
#  ('ralli', 1): 16,
#  ('oz', 1): 8,
#  ('lucozad', 1): 8,
#  ('energi', 1): 14,
#  ('le', 1): 8,
#  ('61200', 1): 8,
#  ('pack', 1): 8,
#  ('lucozade.co.uk/wrc', 1): 8,
#  ('itcould', 1): 8,
#  ('no1', 1): 50,
#  ('36504', 1): 42,
#  ('w4', 1): 7,
#  ('5wq', 1): 7,
#  ('norm', 1): 11,
#  ('å£400', 1): 26,
#  ('comput', 1): 20,
#  ('randomli', 1): 11,
#  ('pick', 1): 24,
#  ('loyal', 1): 11,
#  ('09066380611', 1): 11,
#  ('hard', 1): 9,
#  ('121', 1): 9,
#  ('60p/min', 1): 15,
#  ('connect', 1): 19,
#  ('09094646899', 1): 8,
#  ('cheap', 1): 15,
#  ('biggest', 1): 9,
#  ('vu', 1): 8,
#  ('bcm1896wc1n3xx', 1): 8,
#  ('rental', 1): 52,
#  ('500', 1): 119,
#  ('cross', 1): 9,
#  ('ntwk', 1): 11,
#  ('08001950382', 1): 14,
#  ('call2optout/674', 1): 9,
#  ('order', 1): 62,
#  ('ref', 1): 15,
#  ('k718', 1): 6,
#  ('å£4.50', 1): 25,
#  ('should', 1): 32,
#  ('arriv', 1): 31,
#  ('09065069120', 1): 6,
#  ('125gift', 1): 20,
#  ('lion', 1): 7,
#  ('lionm', 1): 7,
#  ('mono', 1): 17,
#  ...}

# %% [markdown]
# ## Training the Naive Bayes Model: (20 points)
#
# Now we are in the training phase of the Naive Bayes algorithm. In this cell, take a look at the ways to calculate the log likelihood and log prior values as these are important for testing in the next few cells.
#
# Also calculate the frequency of occurrence of words where the output is spam. In the same way, calculate the word frequency count using the above functions in order to compute the log likelihood.
#
# Return the logprior and loglikelihood output by the model from this function.

# %%
def train_naive_bayes(freqs, train_x, train_y):
    '''
    Input:
        freqs: dictionary from (word, label) to how often the word appears
        train_x: a list of messages
        train_y: a list of labels correponding to the messages (0,1)
    Output:
        logprior: the log prior. (equation 3 above)
        loglikelihood: the log likelihood of you Naive bayes equation. (equation 6 above)
    '''
    loglikelihood = {}
    logprior = 0


    # calculate V, the number of unique words in the vocabulary
    vocab = {}
    for (word, label) in list(freqs.keys()):
        if word in vocab:
            vocab[word] += 1
        else:
            vocab[word] = 1
    V = len(vocab)

    # calculate num_pos and num_neg - the total number of positive and negative words for all documents
    num_pos = num_neg = 0
  
    for pair in freqs.keys():
        # if the label is positive (greater than zero)
        if pair[1] > 0:
            # Increment the number of positive words by the count for this (word, label) pair
            num_pos += freqs[pair]
        # else, the label is negative
        else:
            # increment the number of negative words by the count for this (word,label) pair
            num_neg += freqs[pair]
    
    # Calculate num_doc, the number of documents
    num_doc = len(train_x)

    # Calculate D_pos, the number of positive documents 
    pos_num_docs = 0
    for label in train_y:
        if label == 1:
            pos_num_docs += 1
            
    # Calculate D_neg, the number of negative documents 
    neg_num_docs = 0
    for label in y_train:
        if label == 0 :
            neg_num_docs += 1

    # Calculate logprior
    logprior = np.log(pos_num_docs) - np.log(neg_num_docs)

    # For each word in the vocabulary...
    for word in vocab:
        # get the positive and negative frequency of the word
        freq_pos = find_occurrence(freqs, word, 1)
        #freqs[(word,1)] if (word,1) in freqs.keys() else 0
        freq_neg = find_occurrence(freqs, word, 0)
        #freqs[(word,0)] if (word,0) in freqs.keys() else 0

        # calculate the probability that each word is positive, and negative
        p_w_pos = (freq_pos + 1)/(num_pos + V)
        p_w_neg = (freq_neg + 1)/(num_neg + V)

        # calculate the log likelihood of the word
        loglikelihood[word] = np.log(p_w_pos) - np.log(p_w_neg)


    return logprior, loglikelihood

# %%
# You do not have to input any code in this cell, but it is relevant to grading, so please do not change anything
logprior, loglikelihood = train_naive_bayes(freqs, X_train, y_train)
print(logprior)
print(len(loglikelihood))
# Out:
# 0.0
# 6764

# %% [markdown]
# ### Expected Output
#
# 0.0 <br>
# 6763

# %% [markdown]
# ## Implementing Naive Bayes Predict Function: (15 points)
#
# It is now time to make our prediction as to whether a given message is spam or ham respectively.
#
# After adding the log likelihood values, ensure that the output is 1 (spam) if the sum of the log likelihood value is greater than 0 and 0 (ham) if the sum of the log likelihood is less than or equal to 0.

# %%
# TASK 4 CELL

def naive_bayes_predict(message, logprior, loglikelihood):
    '''
    Params:
        message: a string
        logprior: a number
        loglikelihood: a dictionary of words mapping to numbers
    Return:
        total_prob: the sum of all the loglikelihoods of each word in the message (if found in the dictionary) + logprior (a number)

    '''
    
     # process the message to get a list of words
    word_l = clean_message(message)

    # initialize probability to zero
    total_prob = 0

    # add the logprior
    total_prob += logprior

    # check if the word exists in the loglikelihood dictionary
    for word in word_l:
        if word in loglikelihood.keys():
            total_prob += loglikelihood[word]
            #print(loglikelihood[word])
            # add the log likelihood of that word to the probability
            
        
    #print(logprior)
    #print(total_prob)
            
    if total_prob > 0:
        total_prob = 1
    else:
        total_prob = 0
    
    return total_prob

# %%
# You do not have to input any code in this cell, but it is relevant to grading, so please do not change anything

# Experiment with your own message.
my_message = 'She smiled.'
p = naive_bayes_predict(my_message, logprior, loglikelihood)
print('The expected output is', p)
# Out:
# The expected output is 0

# %% [markdown]
# ### Expected Output :
# The expected output is 0

# %% [markdown]
# ## Implementing Naive Bayes Test function: (15 points)
#
# In this function, implement the previous functions such as naive_bayes_predict to get the predictions for the test set.
#
# In addition to this, the function should return the total number of messages that it correctly classified as 'spam' or 'ham'.

# %%
# UNQ_C6 (UNIQUE CELL IDENTIFIER, DO NOT EDIT)
def test_naive_bayes(test_x, test_y, logprior, loglikelihood):
    """
    Input:
        test_x: A list of messages
        test_y: the corresponding labels for the list of messages
        logprior: the logprior
        loglikelihood: a dictionary with the loglikelihoods for each word
    Output:
        accuracy: (# of messages classified correctly)/(total # of message)
    """
    accuracy = 0  

    
    y_hats = []
    for message in test_x:
        # if the prediction is > 0
        if naive_bayes_predict(message, logprior, loglikelihood) > 0:
            # the predicted class is 1
             y_hats.append(1)
        else:
            # otherwise the predicted class is 0
             y_hats.append(0)

    ''' # append the predicted class to the list y_hats
        y_hats = None'''

    # error is the average of the absolute values of the differences between y_hats and test_y
    abs_diff = np.absolute(y_hats - test_y)
    error =  np.mean(abs_diff)

    accuracy = 1 - error

    return accuracy

# %%
print(test_naive_bayes(X_train, y_train, logprior, loglikelihood))
# Out:
# 0.9845

# %%
# For grading purpose only
# You do not have to input any code in this cell, but it is relevant to grading, so please do not change anything

# Run this cell to test your function
for message in ['get an offer', 'get the latest movie review', 'order iphone', 'I am on a meeting']:
    #print( '%s -> %f' % (message, naive_bayes_predict(message, logprior, loglikelihood)))
    p = naive_bayes_predict(message, logprior, loglikelihood)
#     print(f'{message} -> {p:.2f} ({p_category})')
    print(f'{message} -> {p:.2f}')
# Out:
# get an offer -> 1.00
# get the latest movie review -> 1.00
# order iphone -> 1.00
# I am on a meeting -> 0.00

# %% [markdown]
# ### Expected Output :
# get an offer -> 1.00 <br>
# get the latest movie review -> 1.00 <br>
# order iphone -> 1.00 <br>
# I am on a meeting -> 0.00 <br>

# %%
# Feel free to check the sentiment of your own message below
my_message = 'get an offer of iphone 13 and grab your order'
naive_bayes_predict(my_message, logprior, loglikelihood)
# Out:
# 1

# %% [markdown]
# ### Expected Output :
# 1

# %% [markdown]
# ## Theory Questions: (15 points)
#
# 1. When performing Naive Bayes operation especially for text classification, why is there a requirement for Laplace Smoothing or Additive Smoothing? Explain with considering an example of training and the test set and show how not having additive smoothing leads to undesirable outcomes. (10 points)
#
# Solution:
#
# Naive Bayes machine learning algorithm requires Laplace smoothing or any other additive smoothing technique especially for text classification because the smoothing techniques helps in tackling the problem of zero probability.
#
# In Naive Bayes algorithm , our inference is based on a test sequence  𝐱=(𝑥1,𝑥2,…,𝑥𝑛) using the following equation:
#
# y(𝑝𝑟𝑒𝑑) = argmax[ 𝑦𝑃(𝑦)𝑃(𝑥1|𝑦)𝑃(𝑥2|𝑦)…𝑃(𝑥𝑛|𝑦)]
#
# Usually the probabilities in this equation are estimated from the training data by counting the frequency of occurrences of each event.
#
# For Example, while dealing with our spam classification task using our training data set, if we encounter a word ‘flat’ only in spam emails, and never in ham emails. Our estimate will tell us that
#
# 𝑃(flat|ham)=0
#
# This implies that none of the ham emails will contain the word ‘flat'. Now, clearly, this is not true. The probability of this event is low, but it is definitely non zero. Furthermore, because we are multiplying all the probabilities during the inference, even one such zero probability term will lead to the entire process collapsing.
#
# Therefore, we require smoothing as the ultimate aim is to increase the zero probability values to a small positive number and correspondingly reduce other values so that the sum is still 1. And Laplace smoothing is one such method.

# %% [markdown]
# 2. Why are logarithmic values computed for naive bayes algorithm rather than only the probability values? (5 points)
#
# Solution:
#
# Naive Bayes Classification uses the below hypothesis to predict a class:
#
# 𝑦(𝑝𝑟𝑒𝑑) = argmax [𝑦𝑃(𝑦)𝑃(𝑥1|𝑦)𝑃(𝑥2|𝑦)…𝑃(𝑥𝑛|𝑦)]
#
# For the spam classification task, we have two classes, spam and ham. When you implement this calculation in code, a problem arises when the size of the vocabulary becomes very big.
#
# We know that each P(xi|y) term is between 0 and 1, when we start multiplying them together, the overall product starts approaching zero. This is exacerbated by each new feature that is added: with 1,000 features, multiplying 1,000 probabilities together quickly results in an extremely tiny number, one which often cannot be represented in a double or long double. And hence to solve this issue we represent probabilities as log-probabilities.
#
#
# Log-probabilities is always between −∞ and 0 and as a result it provide us a much wider range of numbers whereas in probability our result is always between 0 and 1. Also properties of log function such as :
#
# 1) If a < b, then ln a < ln b
#
# 2) ln(a · b) = ln a + ln b)
#
# Makes Comparisons and Calculations of probabilities managable. And hence we compute logarithmic values instead of probability values for Naive Bayes Algorithm.
